# %%
import pandas as pd
import numpy as np
import joblib
import pickle
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# %%
# Load dataset
dataset = pd.read_csv("Google_Stock_Price_Train.csv")

# %%
# Use Open price
training_set = dataset.iloc[:, 1:2].values

# %%
# Scale data
scaler = MinMaxScaler(feature_range=(0,1))
training_scaled = scaler.fit_transform(training_set)

# %%
# Create sequences
X_train = []
y_train = []

time_step = 60

for i in range(time_step, len(training_scaled)):
    X_train.append(training_scaled[i-time_step:i,0])
    y_train.append(training_scaled[i,0])

X_train = np.array(X_train)
y_train = np.array(y_train)

# %%
# Reshape for LSTM
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
model = Sequential()

model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1],1)))
model.add(Dropout(0.2))

model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(units=50))
model.add(Dropout(0.2))

model.add(Dense(units=1))

model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Train model
model.fit(X_train, y_train, epochs=20, batch_size=32)
# Out:
# Epoch 1/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - loss: 0.0358
# Epoch 2/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0057
# Epoch 3/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0053
# Epoch 4/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - loss: 0.0048
# Epoch 5/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.0046
# Epoch 6/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0042
# Epoch 7/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0043
# Epoch 8/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 0.0043
# Epoch 9/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 0.0037
# Epoch 10/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 0.0035
# Epoch 11/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0034
# Epoch 12/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0034
# Epoch 13/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 0.0046
# Epoch 14/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0032
# Epoch 15/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 0.0031
# Epoch 16/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 0.0033
# Epoch 17/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.0030
# Epoch 18/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0029
# Epoch 19/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 0.0030
# Epoch 20/20
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 0.0029

# %%
# Save scaler
joblib.dump(scaler, "scaler.pkl")

# Save model as pickle
with open("lstm_model.pkl", "wb") as f:
    pickle.dump(model, f)
# Out:
# Model and scaler saved successfully!
