# %%
import pandas as pd

# %%
df=pd.read_csv(r"c:\DATA SCIENCE\Machine_Learning\KNN\Data  Sets\Social_Network_Ads.csv")
df.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
df.isnull().sum()
# Out:
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Age', 'EstimatedSalary', 'Purchased'], dtype='object')

# %%
df.duplicated().sum()
df=df.drop_duplicates()

# %%
x=df[['Age', 'EstimatedSalary']]
y=df["Purchased"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=12,train_size=0.8)

# %%
x_train.shape,x_test.shape
# Out:
# ((293, 2), (74, 2))

# %%
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier(p=4)
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(p=4)

# %%
y_predict=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_predict))
# Out:
# 0.7432432432432432

# %%
! pip install feature-engine
# Out:
# ...
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    -------- ------------------------------- 2.1/9.6 MB 13.1 MB/s eta 0:00:01
#    -------- ------------------------------- 2.1/9.6 MB 13.1 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.6/9.6 MB 4.3 MB/s eta 0:00:02
#    -------------------------- ------------- 6.3/9.6 MB 7.5 MB/s eta 0:00:01
#    ------------------------------- -------- 7.6/9.6 MB 7.5 MB/s eta 0:00:01
#    ------------------------------------ --- 8.7/9.6 MB 7.0 MB/s eta 0:00:01
#    ------------------------------------ --- 8.7/9.6 MB 7.0 MB/s eta 0:00:01
#    ------------------------------------- -- 8.9/9.6 MB 5.3 MB/s eta 0:00:01
#    -------------------------------------- - 9.2/9.6 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------- 9.6/9.6 MB 4.6 MB/s  0:00:02
# ...
#
#    ---------------------------------------- 0/3 [patsy]
#    ---------------------------------------- 0/3 [patsy]
# ...

# %%
import seaborn as sns
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
from feature_engine.outliers import Winsorizer
winsor=Winsorizer(capping_method="iqr")
winsor.fit_transform(df)
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [367 rows x 3 columns]
