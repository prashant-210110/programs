# %%
import pandas as pd
df=pd.read_csv(r"c:\DATA SCIENCE\Machine_Learning\Linear Regression\Data_Sets\Algerian_Forest_Fires.csv",header=1)
df.head()

# %%
df.shape

# %%
df.info()

# %%
print(df.columns)

# %%
df[df.isnull().any(axis=1)]

# %%
df.loc[:122,"region"]=0
df.loc[122:,"region"]=1
dataset=df
dataset.info()

# %%
dataset[["region"]]=dataset[["region"]].astype(int)
dataset.info()

# %%
dataset=dataset.dropna().reset_index(drop=True)
dataset.isnull().sum().sum()

# %%
dataset.iloc[122]
dataset=dataset.drop(122).reset_index(drop=True)
dataset.iloc[122]

# %%
dataset.isnull().sum()

# %%
dataset.columns=df.columns.str.strip()
dataset.columns

# %%
dataset.head(5)

# %%
dataset.columns

# %%
dataset[['day', 'month', 'year', 'Temperature', 'RH', 'Ws']]=dataset[['day', 'month', 'year', 'Temperature', 'RH', 'Ws']].astype(int)

# %%
dataset[['Ws', 'Rain', 'FFMC','DMC', 'DC', 'ISI', 'BUI', 'FWI']]=dataset[['Ws', 'Rain', 'FFMC','DMC', 'DC', 'ISI', 'BUI', 'FWI']].astype(float)

# %%
dataset.info()

# %%
dataset.describe()

# %%
df.head()

# %%
df.columns=df.columns.str.strip()

# %%
df["Classes"].value_counts()

# %%
import numpy as np
df["Classes"]=np.where(df["Classes"].str.contains("not fire"),0,1)
df["Classes"].value_counts()

# %%
df.head()

# %%
df.drop(['day', 'month', 'year'],axis=1,inplace=True)

# %%
df.reset_index(drop=True)

# %%
df[df.isnull().any(axis=1)]

# %% [markdown]
# df.iloc[[122]]

# %%
df.columns

# %%
df.dropna(inplace=True)
df["Temperature"].unique()
df["Temperature"]=df["Temperature"].str.replace('Temperature',"0")
df["Temperature"].unique()
df["Temperature"]=df["Temperature"].astype(float)

# %%
df.columns

# %%
df["Temperature"].unique()
df["Temperature"]=df["Temperature"].str.replace("Temperature","0")

# %%
df["FWI"].unique()
df["FWI"]=df["FWI"].str.replace("FWI","0")

# %%
df["FWI"].unique()
df["FWI"]=df["FWI"].str.replace('fire   ',"0")

# %%
df["BUI"].unique()
df["BUI"]=df["BUI"].str.replace("BUI","0")

# %%
df["ISI"].unique()
df["ISI"]=df["ISI"].str.replace("ISI","0")

# %%
df["DC"].unique()
df["DC"]=df["DC"].str.replace("DC","0")

# %%
df["DMC"].unique()
df["DMC"]=df["DMC"].str.replace("DMC","0")

# %%
df["FFMC"].unique()
df["FFMC"]=df["FFMC"].str.replace("FFMC","0")

# %%
df['Rain'].unique()
df["Rain"]=df["Rain"].str.replace("Rain ","0")

# %%
df['RH'].unique()
df["RH"]=df["RH"].str.replace(" RH","50")

# %%
df['Ws'].unique()
df["Ws"]=df["Ws"].str.replace(" Ws","50")

# %%
for col in df.columns:
    df[col] = df[col].astype(float)

# %%
df.info()

# %%
df["Classes"]=df["Classes"].astype(int)
df["region"]=df["region"].astype(int)

# %%
df.info()

# %%
df.head()

# %%
df["Classes"].value_counts()

# %%
df.columns

# %%
x=df[['Temperature', 'RH', 'Ws', 'Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI','FWI']]
y=df["Classes"]

# %%
from sklearn.utils import resample
maj=df[df["Classes"]==0]
min=df[df["Classes"]==1]
resample(min,replace=True,n_samples=len(maj),random_state=42)

# %%
df["Classes"].value_counts()

# %%
x.shape,y.shape

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("cleaned algeria dataset")
df.head()

# %%
df.info()

# %%
df[df.isnull().any(axis=1)]

# %%
df.columns=df.columns.str.strip()

# %%
df["Classes"].value_counts()

# %%
import numpy as np
df["Classes"]=np.where(df["Classes"].str.contains("not fire"),0,1)

# %%
df.head()

# %%
df.drop(["day","month","year"],axis=1,inplace=True)

# %%
df.head()

# %%
cols=df.columns

# %%
df["Temperature"]=df["Temperature"].str.replace("Temperature","0")
df.dropna(inplace=True)
df.isnull().sum().sum()

# %%
df[df.isnull().any(axis=1)]
df.reset_index()

# %%
df[[122]]

# %%
df.dropna(inplace=True)

# %%
for i in cols:
    df[i]=df[i].astype(float)

# %%
df[df.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 167                             14    07  2012          37   37   18   0.2
#
#      FFMC   DMC     DC   ISI   BUI      FWI Classes    region
# 122   NaN   NaN    NaN   NaN   NaN      NaN       NaN       1
# 167  88.9  12.9  14.69  12.5  10.4  fire          NaN       1

# %%
df=df.drop(122).reset_index(drop=True)

# %%
df[df.isnull().any(axis=1)]
df.dropna(inplace=True)

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [day, month, year, Temperature,  RH,  Ws, Rain , FFMC, DMC, DC, ISI, BUI, FWI, Classes  , region]
# Index: []

# %%
df.columns=df.columns.str.strip()

# %%
df["Classes"]=np.where(df["Classes"].str.contains("not fire"),0,1)

# %%
df.drop(["day","month","year"],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Temperature', 'RH', 'Ws', 'Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI',
#        'FWI', 'Classes', 'region'],
#       dtype='object')

# %%
df["Temperature"]=df["Temperature"].str.replace("Temperature","0")
df["RH"]=df["RH"].str.replace(" RH","0")
df["Ws"]=df["Ws"].str.replace(" Ws","0")
df["Rain"]=df["Rain"].str.replace("Rain ","0")
df["FFMC"]=df["FFMC"].str.replace("FFMC","0")
df["DMC"]=df["DMC"].str.replace("DMC","0")
df["DC"]=df["DC"].str.replace("DC","0")
df["ISI"]=df["ISI"].str.replace("ISI","0")
df["BUI"]=df["BUI"].str.replace("BUI","0")
df["FWI"]=df["FWI"].str.replace("FWI","0")

# %%
for i in df.columns:
    df[i]=df[i].astype(float)

# %%
df.columns
# Out:
# Index(['Temperature', 'RH', 'Ws', 'Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI',
#        'FWI', 'Classes', 'region'],
#       dtype='object')

# %%
df[['Temperature', 'RH', 'Ws', 'Classes', 'region']]=df[['Temperature', 'RH', 'Ws', 'Classes', 'region']].astype(int)

# %%
df[df.isnull().any(axis=1)]
df.dtypes
# Out:
# Temperature      int64
# RH               int64
# Ws               int64
# Rain           float64
# FFMC           float64
# DMC            float64
# DC             float64
# ISI            float64
# BUI            float64
# FWI            float64
# Classes          int64
# region           int64
# dtype: object

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# dependent and independent variables

# %%
x=df.drop("FWI",axis=1)
y=df["FWI"]
x.shape,y.shape
# Out:
# ((244, 11), (244,))

# %% [markdown]
# spliting training and testing data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,train_size=0.853)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((208, 11), (36, 11), (208,), (36,))

# %% [markdown]
# scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled=scaler.transform(x_test)

# %%
x_train_scaled
# Out:
# array([[-0.67955171,  0.7745525 ,  1.14535274, ..., -0.78079948,
#         -1.16774842, -1.02927447],
#        [ 0.73156398, -1.01694621, -0.87642975, ...,  0.1325144 ,
#          0.85634884,  0.97155815],
#        [-0.20917981,  0.45464201,  0.47142524, ..., -0.90348344,
#         -1.16774842,  0.97155815],
#        ...,
#        [-1.6202955 ,  0.90251669,  0.47142524, ..., -1.03979894,
#         -1.16774842, -1.02927447],
#        [ 0.26119209, -0.31314315,  0.1344615 , ..., -0.09240618,
#          0.85634884,  0.97155815],
#        [-0.44436576,  0.96649879,  1.81928023, ..., -0.99890429,
#         -1.16774842, -1.02927447]], shape=(208, 11))

# %%
plt.figure(figsize=(10,6))
plt.subplot(1,2,1)
sns.boxplot(data=x_train)
plt.subplot(1,2,2)
sns.boxplot(data=x_train_scaled)
# Out:
# <Axes: >

# %% [markdown]
# linear regression

# %%
from sklearn.linear_model import LinearRegression
lin=LinearRegression()
lin.fit(x_train_scaled,y_train)
y_predict=lin.predict(x_test_scaled)
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
print(r2_score(y_test,y_predict))
print(mean_absolute_error(y_test,y_predict))
print(mean_squared_error(y_test,y_predict))
# Out:
# 0.9910082996619889
# 0.4693874751739038
# 0.39952927570098534

# %% [markdown]
# lasso

# %%
from sklearn.linear_model import Lasso
lasso=Lasso()
lasso.fit(x_train_scaled,y_train)
y_predict_lasso=lasso.predict(x_test_scaled)
print(r2_score(y_test,y_predict_lasso))
print(mean_absolute_error(y_test,y_predict_lasso))
print(mean_squared_error(y_test,y_predict_lasso))
# Out:
# 0.9563771132784505
# 1.0199029736064822
# 1.9383008419630978

# %%
from sklearn.linear_model import LassoCV
lassocv=LassoCV(cv=5)
lassocv.fit(x_train_scaled,y_train)
y_predict_lassocv=lassocv.predict(x_test_scaled)
print(r2_score(y_test,y_predict_lassocv))
print(mean_absolute_error(y_test,y_predict_lassocv))
print(mean_squared_error(y_test,y_predict_lassocv))
lassocv.get_params()
# Out:
# 0.9890849322292986
# 0.49670701650278004
# 0.48499048641784426
# {'alphas': 'warn',
#  'copy_X': True,
#  'cv': 5,
#  'eps': 0.001,
#  'fit_intercept': True,
#  'max_iter': 1000,
#  'n_alphas': 'deprecated',
#  'n_jobs': None,
#  'positive': False,
#  'precompute': 'auto',
#  'random_state': None,
#  'selection': 'cyclic',
#  'tol': 0.0001,
#  'verbose': False}

# %% [markdown]
# ridge

# %%
from sklearn.linear_model import Ridge
ridge=Ridge()
ridge.fit(x_train_scaled,y_train)
y_predict_ridge=ridge.predict(x_test_scaled)
print(r2_score(y_test,y_predict_ridge))
print(mean_absolute_error(y_test,y_predict_ridge))
print(mean_squared_error(y_test,y_predict_ridge))
# Out:
# 0.9905421024607499
# 0.47437201699973586
# 0.42024387062108787

# %%
import pickle
pickle.dump(ridge,open("ridge","wb"))

# %%
pickle.load(open("ridge","rb"))
# Out:
# Ridge()

# %%
from sklearn.linear_model import RidgeCV
ridgecv=RidgeCV(cv=5)
ridgecv.fit(x_train_scaled,y_train)
y_predict_ridgecv=lassocv.predict(x_test_scaled)
print(r2_score(y_test,y_predict_ridgecv))
print(mean_absolute_error(y_test,y_predict_ridgecv))
print(mean_squared_error(y_test,y_predict_ridgecv))
lassocv.get_params()
# Out:
# 0.9890849322292986
# 0.49670701650278004
# 0.48499048641784426
# {'alphas': 'warn',
#  'copy_X': True,
#  'cv': 5,
#  'eps': 0.001,
#  'fit_intercept': True,
#  'max_iter': 1000,
#  'n_alphas': 'deprecated',
#  'n_jobs': None,
#  'positive': False,
#  'precompute': 'auto',
#  'random_state': None,
#  'selection': 'cyclic',
#  'tol': 0.0001,
#  'verbose': False}

# %% [markdown]
# elasticnet

# %%
from sklearn.linear_model import ElasticNet
e_net=ElasticNet()
e_net.fit(x_train_scaled,y_train)
y_predict_enet=ridge.predict(x_test_scaled)
print(r2_score(y_test,y_predict_enet))
print(mean_absolute_error(y_test,y_predict_enet))
print(mean_squared_error(y_test,y_predict_enet))
# Out:
# 0.9905421024607499
# 0.47437201699973586
# 0.42024387062108787

# %%
from sklearn.linear_model import ElasticNetCV
e_netcv=ElasticNetCV()
e_netcv.fit(x_train_scaled,y_train)
y_predict_enetcv=ridge.predict(x_test_scaled)
print(r2_score(y_test,y_predict_enetcv))
print(mean_absolute_error(y_test,y_predict_enetcv))
print(mean_squared_error(y_test,y_predict_enetcv))
# Out:
# 0.9905421024607499
# 0.47437201699973586
# 0.42024387062108787
