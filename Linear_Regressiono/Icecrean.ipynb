# %%
import pandas as pd
df=pd.read_csv(r"c:\DATA SCIENCE\Machine_Learning\Linear Regression\Data_Sets\Ice_cream selling data.csv")
df.head()
# Out:
#    Temperature (°C)  Ice Cream Sales (units)
# 0         -4.662263                41.842986
# 1         -4.316559                34.661120
# 2         -4.213985                39.383001
# 3         -3.949661                37.539845
# 4         -3.578554                32.284531

# %%
df.shape
# Out:
# (49, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Temperature (°C)         49 non-null     float64
#  1   Ice Cream Sales (units)  49 non-null     float64
# dtypes: float64(2)
# memory usage: 916.0 bytes

# %%
df.describe()
# Out:
#        Temperature (°C)  Ice Cream Sales (units)
# count         49.000000                49.000000
# mean           0.271755                15.905308
# std            2.697672                12.264682
# min           -4.662263                 0.328626
# 25%           -2.111870                 4.857988
# 50%            0.688781                12.615181
# 75%            2.784836                25.142082
# max            4.899032                41.842986

# %%
df.isnull().sum()
# Out:
# Temperature (°C)           0
# Ice Cream Sales (units)    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['Temperature (°C)', 'Ice Cream Sales (units)'], dtype='object')

# %%
x=df[['Temperature (°C)']]
y=df['Ice Cream Sales (units)']

# %%
import matplotlib.pyplot as plt
plt.scatter(df['Temperature (°C)'],df['Ice Cream Sales (units)'])

# %%
df.corr
# Out:
# <bound method DataFrame.corr of     Temperature (°C)  Ice Cream Sales (units)
# 0          -4.662263                41.842986
# 1          -4.316559                34.661120
# 2          -4.213985                39.383001
# 3          -3.949661                37.539845
# 4          -3.578554                32.284531
# 5          -3.455712                30.001138
# 6          -3.108440                22.635401
# 7          -3.081303                25.365022
# 8          -2.672461                19.226970
# 9          -2.652287                20.279679
# 10         -2.651498                13.275828
# 11         -2.288264                18.123991
# 12         -2.111870                11.218294
# 13         -1.818938                10.012868
# 14         -1.660348                12.615181
# 15         -1.326379                10.957731
# 16         -1.173123                 6.689123
# 17         -0.773330                 9.392969
# 18         -0.673753                 5.210163
# ...

# %%
import seaborn as sns
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
# Out:
# ['Temperature (°C)']

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=20)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((39, 1), (10, 1), (39,), (10,))

# %%
from sklearn.preprocessing import PolynomialFeatures 
#sklearn.preprocessing.PolynomialFeatures(degree=2, *, interaction_only=False, include_bias=True, order='C')[source]
model=PolynomialFeatures(degree=3)
model.fit(x_train,y_train)
# Out:
# PolynomialFeatures(degree=3)
