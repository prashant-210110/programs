# %%
x=int(input("enter the number"))
a=x
sum=0
b=len(str(x))
while x!=0:
  d=x%10
  sum=sum+d**b
  x=x//10
if sum==a:
  print(a,"is armstrong")
else:
  print(a,"is not armstrong")
# Out:
# 9 is armstrong

# %%
for i in range(1,100):
    a=i
    b=len(str(i))
    sum=0
    while b!=0:
        d=x%10
        sum=sum+d**b
        x=x//10
    if sum==a:
        print(a)
    else:
        pass
