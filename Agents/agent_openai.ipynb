# %%
import os
from phi.agent import Agent
from phi.model.openai import OpenAIChat
from phi.tools.duckduckgo import DuckDuckGo

# 1. Set your open ai API Key
os.environ["OPENAI_API_KEY"]="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"

# 2. Create the Agent
agent1 = Agent(
    name="open ai Search Agent",
    model=OpenAIChat(id="gpt-4o-mini"), # You can also use "gemini-1.5-pro"
    tools=[DuckDuckGo()],
    instructions=[
        "Search for the user's query using DuckDuckGo.",
        "Provide a concise summary of the findings.",
        "Always include the sources/links for the information found."
    ],
    markdown=True,
)

# 3. Run the Agent
# Run the agent with a query
response = agent1.run("WHAT is difference between agentic ai and ai agents")

# Print the response
print(response)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[3], line 24
#      10 agent1 = Agent(
#      11     name="open ai Search Agent",
#      12     model=OpenAIChat(id="gpt-4o-mini"), # You can also use "gemini-1.5-pro"
#    (...)     19     markdown=True,
#      20 )
#      22 # 3. Run the Agent
#      23 # Run the agent with a query
# ---> 24 response = agent1.run("WHAT is difference between agentic ai and ai agents")
#      26 # Print the response
#      27 print(response)
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\phi\agent\agent.py:2074, in Agent.run(self, message, stream, audio, images, videos, messages, stream_intermediate_steps, **kwargs)
#    2063 else:
#    2064     resp = self._run(
#    2065         message=message,
#    2066         stream=False,
#    (...)   2072         **kwargs,
#    2073     )
# ...
