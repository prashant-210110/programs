# %%
import os

os.environ["GOOGLE_API_KEY"]="AIzaSyBQqNGwQ8IwcaXy5Cy91hUkgggOpIhgK2s"

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

gemini_llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",   # or "gemini-1.5-pro"
    temperature=0.7,
    verbose=True,
)

# %%
from crewai import Agent,Crew
from phi.model.google import Gemini


translator = Agent(
    role="Language Translator",
    goal="Translate text to the user's requested language accurately",
    backstory="Expert linguist fluent in multiple languages.",
    verbose=True,
    allow_delegation=False,
    llm=gemini_llm
    
)
translator
# Out:
# Agent(role=Language Translator, goal=Translate text to the user's requested language accurately, backstory=Expert linguist fluent in multiple languages.)

# %%
summarizer = Agent(model=Gemini(id="gemini-2.5-flash"),    role="summaring the text",
    goal="summarize the text into main points which contain 5 to 8 bullet points,and give the output in the user required langauge",
    backstory="Skilled at distilling complex information into clear summaries.",
    verbose=True,
    allow_delegation=False,
    llm=gemini_llm
)
summarizer
# Out:
# Agent(role=summaring the text, goal=summarize the text into main points which contain 5 to 8 bullet points,and give the output in the user required langauge, backstory=Skilled at distilling complex information into clear summaries.)

# %%
from crewai import Task
translator_task = Task(
    description="Translate the following paragraph to {target_language}: {paragraph}",
    expected_output="The complete translated text in {target_language}",
    agent=translator
)
translator_task
# Out:
# Task(description=Translate the following paragraph to {target_language}: {paragraph}, expected_output=The complete translated text in {target_language})

# %%
summarizer_task = Task(
    description="give some bullet points in {target_language} for the following paragraph: {paragraph}",
    expected_output="bullet poiont summary in {target_language}",
    agent=summarizer
)

# %%
crew=Crew(
    agents=[translator,summarizer],
    tasks=[translator_task,summarizer_task],
    verbose=True
)

# %%
result = crew.kickoff(inputs={
    "paragraph": "Artificial intelligence is transforming how we work and live.",
    "target_language": "Telugu"
})

print("Final Result:", result)
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 0667054d-9cdc-47ef-bc1f-471a9cae32a6                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\live.py:256: UserWarning: install
# "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# 🚀 Crew: crew
# └── 📋 Task: 200a251d-a730-4e8f-87b8-93f60d277044
#     Status: Executing Task...
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Language Translator                                                                                     │
# │                                                                                                                 │
# │  Task: Translate the following paragraph to Telugu: Artificial intelligence is transforming how we work and     │
# │  live.                                                                                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\live.py:256: UserWarning: install
# "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# 🚀 Crew: crew
# └── 📋 Task: 200a251d-a730-4e8f-87b8-93f60d277044
#     Assigned to: Language Translator
#     Status: ✅ Completed
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Language Translator                                                                                     │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  కృత్రిమ మేధస్సు మనం పని చేసే మరియు జీవించే విధానాన్ని మారుస్తోంది.                                                                        │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 200a251d-a730-4e8f-87b8-93f60d277044                                                                     │
# │  Agent: Language Translator                                                                                     │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 🚀 Crew: crew
# ├── 📋 Task: 200a251d-a730-4e8f-87b8-93f60d277044
# │   Assigned to: Language Translator
# │   Status: ✅ Completed
# └── 📋 Task: 73fdeb12-5325-45f5-b755-ebfb1cf25158
#     Status: Executing Task...
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: summaring the text                                                                                      │
# │                                                                                                                 │
# │  Task: give some bullet points in Telugu for the following paragraph: Artificial intelligence is transforming   │
# │  how we work and live.                                                                                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\live.py:256: UserWarning: install
# "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# 🚀 Crew: crew
# ├── 📋 Task: 200a251d-a730-4e8f-87b8-93f60d277044
# │   Assigned to: Language Translator
# │   Status: ✅ Completed
# └── 📋 Task: 73fdeb12-5325-45f5-b755-ebfb1cf25158
#     Assigned to: summaring the text
#     Status: ✅ Completed
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 73fdeb12-5325-45f5-b755-ebfb1cf25158                                                                     │
# │  Agent: summaring the text                                                                                      │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: summaring the text                                                                                      │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  *   కృత్రిమ మేధస్సు                                                                                                  │
# │  *   పని చేసే విధానాలలో మార్పులు                                                                                           │
# │  *   జీవనశైలిలో పరివర్తన                                                                                              │
# │  *   ఇది దైనందిన కార్యకలాపాలను ప్రభావితం చేస్తోంది                                                                                │
# │  *   వృత్తిపరమైన రంగాలలో నూతన ఆవిష్కరణలు                                                                                   │
# │  *   సమగ్రమైన సామాజిక మార్పులకు దారితీస్తోంది                                                                                   │
# │  *   మన భవిష్యత్తును పునర్నిర్మిస్తోంది                                                                                       │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\console.py:1698, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1697 with self:
# -> 1698     renderables = self._collect_renderables(
#    1699         objects,
#    1700         sep,
#    1701         end,
#    1702         justify=justify,
#    1703         emoji=emoji,
#    1704         markup=markup,
#    1705         highlight=highlight,
#    1706     )
#    1707     for hook in render_hooks:
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\console.py:1558, in Console._collect_renderables(self, objects, sep, end, justify, emoji, markup, highlight)
#    1556 if isinstance(renderable, str):
#    1557     append_text(
# -> 1558         self.render_str(
#    1559             renderable,
#    1560             emoji=emoji,
#    1561             markup=markup,
#    1562             highlight=highlight,
#    1563             highlighter=_highlighter,
#    1564         )
#    1565     )
#    1566 elif isinstance(renderable, Text):
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\console.py:1470, in Console.render_str(self, text, style, justify, overflow, emoji, markup, highlight, highlighter)
#    1469 if _highlighter is not None:
# -> 1470     highlight_text = _highlighter(str(rich_text))
#    1471     highlight_text.copy_styles(rich_text)
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\highlighter.py:38, in Highlighter.__call__(self, text)
#      37     raise TypeError(f"str or Text instance required, not {text!r}")
# ---> 38 self.highlight(highlight_text)
#      39 return highlight_text
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\highlighter.py:77, in RegexHighlighter.highlight(self, text)
#      76 for re_highlight in self.highlights:
# ---> 77     highlight_regex(re_highlight, style_prefix=self.base_style)
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\text.py:615, in Text.highlight_regex(self, re_highlight, style, style_prefix)
#     614 _Span = Span
# --> 615 plain = self.plain
#     616 if isinstance(re_highlight, str):
#
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# RecursionError                            Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[101], line 6
#       1 result = crew.kickoff(inputs={
#       2     "paragraph": "Artificial intelligence is transforming how we work and live.",
#       3     "target_language": "Telugu"
#       4 })
# ----> 6 print("Final Result:", result)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:3045, in InteractiveShell._tee.<locals>.write(data, *args, **kwargs)
#    3044 """Write data to both the original destination and the capture dictionary."""
# -> 3045 result = original_write(data, *args, **kwargs)
#    3046 if any(
#    3047     [
#    3048         self.display_pub.is_publishing,
#    (...)   3051     ]
#    3052 ):
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\file_proxy.py:43, in FileProxy.write(self, text)
#      42 console = self.__console
# ---> 43 with console:
#      44     output = Text("\n").join(
#      45         self.__ansi_decoder.decode_line(line) for line in lines
#      46     )
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\console.py:870, in Console.__exit__(self, exc_type, exc_value, traceback)
#     869 """Exit buffer context."""
# --> 870 self._exit_buffer()
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\console.py:826, in Console._exit_buffer(self)
#     825 self._buffer_index -= 1
# --> 826 self._check_buffer()
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\console.py:2038, in Console._check_buffer(self)
#    2037 try:
# -> 2038     self._write_buffer()
#    2039 except BrokenPipeError:
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\console.py:2054, in Console._write_buffer(self)
#    2052 from .jupyter import display
# -> 2054 display(self._buffer, self._render_buffer(self._buffer[:]))
#    2055 del self._buffer[:]
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\display_functions.py:285, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     284             _merge(md_dict, metadata)
# --> 285         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     286 if display_id:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\display_functions.py:73, in publish_display_data(data, metadata, transient, **kwargs)
#      71     kwargs['transient'] = transient
# ---> 73 display_pub.publish(
#      74     data=data,
#      75     metadata=metadata,
#      76     **kwargs
#      77 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ipykernel\zmqshell.py:103, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update)
#      88 """Publish a display-data message
#      89
#      90 Parameters
#    (...)    101     If True, send an update_display_data message instead of display_data.
#     102 """
# --> 103 self._flush_streams()
#     104 if metadata is None:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ipykernel\zmqshell.py:66, in ZMQDisplayPublisher._flush_streams(self)
#      65 """flush IO Streams prior to display"""
# ---> 66 sys.stdout.flush()
#      67 sys.stderr.flush()
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\console.py:1697, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1696 render_hooks = self._render_hooks[:]
# -> 1697 with self:
#    1698     renderables = self._collect_renderables(
#    1699         objects,
#    1700         sep,
#    (...)   1705         highlight=highlight,
#    1706     )
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\console.py:870, in Console.__exit__(self, exc_type, exc_value, traceback)
#     869 """Exit buffer context."""
# --> 870 self._exit_buffer()
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\console.py:826, in Console._exit_buffer(self)
#     825 self._buffer_index -= 1
# --> 826 self._check_buffer()
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\console.py:2038, in Console._check_buffer(self)
#    2037 try:
# -> 2038     self._write_buffer()
#    2039 except BrokenPipeError:
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\console.py:2054, in Console._write_buffer(self)
#    2052 from .jupyter import display
# -> 2054 display(self._buffer, self._render_buffer(self._buffer[:]))
#    2055 del self._buffer[:]
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\display_functions.py:285, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     284             _merge(md_dict, metadata)
# --> 285         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     286 if display_id:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\display_functions.py:73, in publish_display_data(data, metadata, transient, **kwargs)
#      71     kwargs['transient'] = transient
# ---> 73 display_pub.publish(
#      74     data=data,
#      75     metadata=metadata,
#      76     **kwargs
#      77 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ipykernel\zmqshell.py:103, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update)
#      88 """Publish a display-data message
#      89
#      90 Parameters
#    (...)    101     If True, send an update_display_data message instead of display_data.
#     102 """
# --> 103 self._flush_streams()
#     104 if metadata is None:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ipykernel\zmqshell.py:66, in ZMQDisplayPublisher._flush_streams(self)
#      65 """flush IO Streams prior to display"""
# ---> 66 sys.stdout.flush()
#      67 sys.stderr.flush()
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\console.py:1697, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1696 render_hooks = self._render_hooks[:]
# -> 1697 with self:
#    1698     renderables = self._collect_renderables(
#    1699         objects,
#    1700         sep,
#    (...)   1705         highlight=highlight,
#    1706     )
#
#     [... skipping similar frames: Console.__exit__ at line 870 (268 times), Console._check_buffer at line 2038 (268 times), Console._exit_buffer at line 826 (268 times), Console._write_buffer at line 2054 (268 times), ZMQDisplayPublisher._flush_streams at line 66 (267 times), display at line 91 (267 times), display at line 285 (267 times), FileProxy.flush at line 53 (267 times), Console.print at line 1697 (267 times), ZMQDisplayPublisher.publish at line 103 (267 times), publish_display_data at line 73 (267 times)]
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\display_functions.py:285, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     284             _merge(md_dict, metadata)
# --> 285         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     286 if display_id:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\display_functions.py:73, in publish_display_data(data, metadata, transient, **kwargs)
#      71     kwargs['transient'] = transient
# ---> 73 display_pub.publish(
#      74     data=data,
#      75     metadata=metadata,
#      76     **kwargs
#      77 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ipykernel\zmqshell.py:103, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update)
#      88 """Publish a display-data message
#      89
#      90 Parameters
#    (...)    101     If True, send an update_display_data message instead of display_data.
#     102 """
# --> 103 self._flush_streams()
#     104 if metadata is None:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ipykernel\zmqshell.py:66, in ZMQDisplayPublisher._flush_streams(self)
#      65 """flush IO Streams prior to display"""
# ---> 66 sys.stdout.flush()
#      67 sys.stderr.flush()
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\console.py:1697, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1696 render_hooks = self._render_hooks[:]
# -> 1697 with self:
#    1698     renderables = self._collect_renderables(
#    1699         objects,
#    1700         sep,
#    (...)   1705         highlight=highlight,
#    1706     )
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\console.py:870, in Console.__exit__(self, exc_type, exc_value, traceback)
#     869 """Exit buffer context."""
# --> 870 self._exit_buffer()
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\console.py:826, in Console._exit_buffer(self)
#     825 self._buffer_index -= 1
# --> 826 self._check_buffer()
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\console.py:2038, in Console._check_buffer(self)
#    2037 try:
# -> 2038     self._write_buffer()
#    2039 except BrokenPipeError:
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\console.py:2054, in Console._write_buffer(self)
#    2052 from .jupyter import display
# -> 2054 display(self._buffer, self._render_buffer(self._buffer[:]))
#    2055 del self._buffer[:]
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\console.py:2121, in Console._render_buffer(self, buffer)
#    2120 legacy_windows = self.legacy_windows
# -> 2121 not_terminal = not self.is_terminal
#    2122 if self.no_color and color_system:
#
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# RecursionError                            Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\formatters.py:282, in catch_format_error(method, self, *args, **kwargs)
#     281 try:
# --> 282     r = method(self, *args, **kwargs)
#     283 except NotImplementedError:
#     284     # don't warn on NotImplementedErrors
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\formatters.py:975, in IPythonDisplayFormatter.__call__(self, obj)
#     974 try:
# --> 975     printer = self.lookup(obj)
#     976 except KeyError:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\formatters.py:456, in BaseFormatter.lookup(self, obj)
#     455 # then lookup by type
# --> 456 return self.lookup_by_type(_get_type(obj))
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\formatters.py:486, in BaseFormatter.lookup_by_type(self, typ)
#     485 for cls in pretty._get_mro(typ):
# --> 486     if cls in self.type_printers or self._in_deferred_types(cls):
#     487         return self.type_printers[cls]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\formatters.py:623, in BaseFormatter._in_deferred_types(self, cls)
#     622 key = (mod, name)
# --> 623 if key in self.deferred_printers:
#     624     # Move the printer over to the regular registry.
#     625     printer = self.deferred_printers.pop(key)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\traitlets\traitlets.py:687, in TraitType.__get__(self, obj, cls)
#     686 else:
# --> 687     return t.cast(G, self.get(obj, cls))
#
# File ~\AppData\Roaming\Python\Python313\site-packages\traitlets\traitlets.py:666, in TraitType.get(self, obj, cls)
#     665 else:
# --> 666     return t.cast(G, value)
#
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# RecursionError                            Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:2194, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2193     else:
# -> 2194         stb = self.InteractiveTB.structured_traceback(
#    2195             etype, value, tb, tb_offset=tb_offset
#    2196         )
#    2198 except Exception:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\ultratb.py:1179, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1178     self.tb = etb
# -> 1179 return FormattedTB.structured_traceback(
#    1180     self, etype, evalue, etb, tb_offset, context
#    1181 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\ultratb.py:1050, in FormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#    1048 if mode in self.verbose_modes:
#    1049     # Verbose modes need a full traceback
# -> 1050     return VerboseTB.structured_traceback(
#    1051         self, etype, evalue, etb, tb_offset, context
#    1052     )
#    1053 elif mode == "Docs":
#    1054     # return DocTB
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\ultratb.py:858, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     857 """Return a nice text document describing the traceback."""
# --> 858 formatted_exceptions: list[list[str]] = self.format_exception_as_a_whole(
#     859     etype, evalue, etb, context, tb_offset
#     860 )
#     862 termsize = min(75, get_terminal_size()[0])
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\ultratb.py:742, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, context, tb_offset)
#     741 assert isinstance(tb_offset, int)
# --> 742 head = self.prepare_header(str(etype), self.long_header)
#     743 records = self.get_records(etb, context, tb_offset) if etb else []
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\ultratb.py:658, in VerboseTB.prepare_header(self, etype, long_version)
#     657 def prepare_header(self, etype: str, long_version: bool = False) -> str:
# --> 658     width = min(75, get_terminal_size()[0])
#     659     if long_version:
#     660         # Header with the exception type, python version, and date
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\utils\terminal.py:125, in get_terminal_size(defaultx, defaulty)
#     124 def get_terminal_size(defaultx: int = 80, defaulty: int = 25) -> tuple[int, int]:
# --> 125     return _get_terminal_size((defaultx, defaulty))
#
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# RecursionError                            Traceback (most recent call last)
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\file_proxy.py:44, in FileProxy.write(self, text)
#      43 with console:
# ---> 44     output = Text("\n").join(
#      45         self.__ansi_decoder.decode_line(line) for line in lines
#      46     )
#      47     console.print(output)
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\text.py:806, in Text.join(self, lines)
#     804 _Span = Span
# --> 806 for text in iter_text():
#     807     extend_text(text._text)
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\text.py:793, in Text.join.<locals>.iter_text()
#     792 if self.plain:
# --> 793     for last, line in loop_last(lines):
#     794         yield line
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\_loop.py:22, in loop_last(values)
#      21 try:
# ---> 22     previous_value = next(iter_values)
#      23 except StopIteration:
#
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# RecursionError                            Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:2205, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2202         traceback.print_exc()
#    2203         return None
# -> 2205     self._showtraceback(etype, value, stb)
#    2206 if self.call_pdb:
#    2207     # drop into debugger
#    2208     self.debugger(force=True)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ipykernel\zmqshell.py:581, in ZMQInteractiveShell._showtraceback(self, etype, evalue, stb)
#     579 def _showtraceback(self, etype, evalue, stb):
#     580     # try to preserve ordering of tracebacks and print statements
# --> 581     sys.stdout.flush()
#     582     sys.stderr.flush()
#     584     exc_content = {
#     585         "traceback": stb,
#     586         "ename": str(etype.__name__),
#     587         "evalue": str(evalue),
#     588     }
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      51 output = "".join(self.__buffer)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\console.py:1697, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1695     crop = False
#    1696 render_hooks = self._render_hooks[:]
# -> 1697 with self:
#    1698     renderables = self._collect_renderables(
#    1699         objects,
#    1700         sep,
#    (...)   1705         highlight=highlight,
#    1706     )
#    1707     for hook in render_hooks:
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\console.py:870, in Console.__exit__(self, exc_type, exc_value, traceback)
#     868 def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any) -> None:
#     869     """Exit buffer context."""
# --> 870     self._exit_buffer()
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\console.py:826, in Console._exit_buffer(self)
#     824 """Leave buffer context, and render content if required."""
#     825 self._buffer_index -= 1
# --> 826 self._check_buffer()
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\console.py:2038, in Console._check_buffer(self)
#    2035     return
#    2037 try:
# -> 2038     self._write_buffer()
#    2039 except BrokenPipeError:
#    2040     self.on_broken_pipe()
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\console.py:2054, in Console._write_buffer(self)
#    2051 if self.is_jupyter:  # pragma: no cover
#    2052     from .jupyter import display
# -> 2054     display(self._buffer, self._render_buffer(self._buffer[:]))
#    2055     del self._buffer[:]
#    2056 else:
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      88 try:
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#      95     pass
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\display_functions.py:285, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     282         if metadata:
#     283             # kwarg-specified metadata gets precedence
#     284             _merge(md_dict, metadata)
# --> 285         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     286 if display_id:
#     287     return DisplayHandle(display_id)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\display_functions.py:73, in publish_display_data(data, metadata, transient, **kwargs)
#      70 if transient:
#      71     kwargs['transient'] = transient
# ---> 73 display_pub.publish(
#      74     data=data,
#      75     metadata=metadata,
#      76     **kwargs
#      77 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ipykernel\zmqshell.py:103, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update)
#      81 def publish(
#      82     self,
#      83     data,
#    (...)     86     update=False,
#      87 ):
#      88     """Publish a display-data message
#      89
#      90     Parameters
#    (...)    101         If True, send an update_display_data message instead of display_data.
#     102     """
# --> 103     self._flush_streams()
#     104     if metadata is None:
#     105         metadata = {}
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ipykernel\zmqshell.py:66, in ZMQDisplayPublisher._flush_streams(self)
#      64 def _flush_streams(self):
#      65     """flush IO Streams prior to display"""
# ---> 66     sys.stdout.flush()
#      67     sys.stderr.flush()
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      51 output = "".join(self.__buffer)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\console.py:1697, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1695     crop = False
#    1696 render_hooks = self._render_hooks[:]
# -> 1697 with self:
#    1698     renderables = self._collect_renderables(
#    1699         objects,
#    1700         sep,
#    (...)   1705         highlight=highlight,
#    1706     )
#    1707     for hook in render_hooks:
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\console.py:870, in Console.__exit__(self, exc_type, exc_value, traceback)
#     868 def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any) -> None:
#     869     """Exit buffer context."""
# --> 870     self._exit_buffer()
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\console.py:826, in Console._exit_buffer(self)
#     824 """Leave buffer context, and render content if required."""
#     825 self._buffer_index -= 1
# --> 826 self._check_buffer()
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\console.py:2038, in Console._check_buffer(self)
#    2035     return
#    2037 try:
# -> 2038     self._write_buffer()
#    2039 except BrokenPipeError:
#    2040     self.on_broken_pipe()
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\console.py:2054, in Console._write_buffer(self)
#    2051 if self.is_jupyter:  # pragma: no cover
#    2052     from .jupyter import display
# -> 2054     display(self._buffer, self._render_buffer(self._buffer[:]))
#    2055     del self._buffer[:]
#    2056 else:
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      88 try:
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#      95     pass
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\display_functions.py:285, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     282         if metadata:
#     283             # kwarg-specified metadata gets precedence
#     284             _merge(md_dict, metadata)
# --> 285         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     286 if display_id:
#     287     return DisplayHandle(display_id)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\display_functions.py:73, in publish_display_data(data, metadata, transient, **kwargs)
#      70 if transient:
#      71     kwargs['transient'] = transient
# ---> 73 display_pub.publish(
#      74     data=data,
#      75     metadata=metadata,
#      76     **kwargs
#      77 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ipykernel\zmqshell.py:103, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update)
#      81 def publish(
#      82     self,
#      83     data,
#    (...)     86     update=False,
#      87 ):
#      88     """Publish a display-data message
#      89
#      90     Parameters
#    (...)    101         If True, send an update_display_data message instead of display_data.
#     102     """
# --> 103     self._flush_streams()
#     104     if metadata is None:
#     105         metadata = {}
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ipykernel\zmqshell.py:66, in ZMQDisplayPublisher._flush_streams(self)
#      64 def _flush_streams(self):
#      65     """flush IO Streams prior to display"""
# ---> 66     sys.stdout.flush()
#      67     sys.stderr.flush()
#
#     [... skipping similar frames: Console.__exit__ at line 870 (267 times), Console._check_buffer at line 2038 (267 times), Console._exit_buffer at line 826 (267 times), Console._write_buffer at line 2054 (267 times), display at line 91 (267 times), FileProxy.flush at line 53 (267 times), Console.print at line 1697 (267 times), ZMQDisplayPublisher._flush_streams at line 66 (266 times), display at line 285 (266 times), ZMQDisplayPublisher.publish at line 103 (266 times), publish_display_data at line 73 (266 times)]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\display_functions.py:285, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     282         if metadata:
#     283             # kwarg-specified metadata gets precedence
#     284             _merge(md_dict, metadata)
# --> 285         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     286 if display_id:
#     287     return DisplayHandle(display_id)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\display_functions.py:73, in publish_display_data(data, metadata, transient, **kwargs)
#      70 if transient:
#      71     kwargs['transient'] = transient
# ---> 73 display_pub.publish(
#      74     data=data,
#      75     metadata=metadata,
#      76     **kwargs
#      77 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ipykernel\zmqshell.py:103, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update)
#      81 def publish(
#      82     self,
#      83     data,
#    (...)     86     update=False,
#      87 ):
#      88     """Publish a display-data message
#      89
#      90     Parameters
#    (...)    101         If True, send an update_display_data message instead of display_data.
#     102     """
# --> 103     self._flush_streams()
#     104     if metadata is None:
#     105         metadata = {}
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ipykernel\zmqshell.py:66, in ZMQDisplayPublisher._flush_streams(self)
#      64 def _flush_streams(self):
#      65     """flush IO Streams prior to display"""
# ---> 66     sys.stdout.flush()
#      67     sys.stderr.flush()
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      51 output = "".join(self.__buffer)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\console.py:1697, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1695     crop = False
#    1696 render_hooks = self._render_hooks[:]
# -> 1697 with self:
#    1698     renderables = self._collect_renderables(
#    1699         objects,
#    1700         sep,
#    (...)   1705         highlight=highlight,
#    1706     )
#    1707     for hook in render_hooks:
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\console.py:870, in Console.__exit__(self, exc_type, exc_value, traceback)
#     868 def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any) -> None:
#     869     """Exit buffer context."""
# --> 870     self._exit_buffer()
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\console.py:826, in Console._exit_buffer(self)
#     824 """Leave buffer context, and render content if required."""
#     825 self._buffer_index -= 1
# --> 826 self._check_buffer()
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\console.py:2038, in Console._check_buffer(self)
#    2035     return
#    2037 try:
# -> 2038     self._write_buffer()
#    2039 except BrokenPipeError:
#    2040     self.on_broken_pipe()
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\console.py:2054, in Console._write_buffer(self)
#    2051 if self.is_jupyter:  # pragma: no cover
#    2052     from .jupyter import display
# -> 2054     display(self._buffer, self._render_buffer(self._buffer[:]))
#    2055     del self._buffer[:]
#    2056 else:
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      88 try:
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#      95     pass
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\display_functions.py:278, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     276     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     277 else:
# --> 278     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     279     if not format_dict:
#     280         # nothing to display (e.g. _ipython_display_ took over)
#     281         continue
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\formatters.py:204, in DisplayFormatter.format(self, obj, include, exclude)
#     201 format_dict = {}
#     202 md_dict = {}
# --> 204 if self.ipython_display_formatter(obj):
#     205     # object handled itself, don't proceed
#     206     return {}, {}
#     208 format_dict, md_dict = self.mimebundle_formatter(obj, include=include, exclude=exclude)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\decorator.py:235, in decorate.<locals>.fun(*args, **kw)
#     233 if not kwsyntax:
#     234     args, kw = fix(args, kw, sig)
# --> 235 return caller(func, *(extras + args), **kw)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\formatters.py:290, in catch_format_error(method, self, *args, **kwargs)
#     288 ip = get_ipython()
#     289 if ip is not None:
# --> 290     ip.showtraceback(exc_info)
#     291 else:
#     292     traceback.print_exception(*exc_info)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:2199, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2194         stb = self.InteractiveTB.structured_traceback(
#    2195             etype, value, tb, tb_offset=tb_offset
#    2196         )
#    2198 except Exception:
# -> 2199     print(
#    2200         "Unexpected exception formatting exception. Falling back to standard exception"
#    2201     )
#    2202     traceback.print_exc()
#    2203     return None
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:3045, in InteractiveShell._tee.<locals>.write(data, *args, **kwargs)
#    3043 def write(data, *args, **kwargs):
#    3044     """Write data to both the original destination and the capture dictionary."""
# -> 3045     result = original_write(data, *args, **kwargs)
#    3046     if any(
#    3047         [
#    3048             self.display_pub.is_publishing,
#    (...)   3051         ]
#    3052     ):
#    3053         return result
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\file_proxy.py:43, in FileProxy.write(self, text)
#      41 if lines:
#      42     console = self.__console
# ---> 43     with console:
#      44         output = Text("\n").join(
#      45             self.__ansi_decoder.decode_line(line) for line in lines
#      46         )
#      47         console.print(output)
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\console.py:870, in Console.__exit__(self, exc_type, exc_value, traceback)
#     868 def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any) -> None:
#     869     """Exit buffer context."""
# --> 870     self._exit_buffer()
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\console.py:826, in Console._exit_buffer(self)
#     824 """Leave buffer context, and render content if required."""
#     825 self._buffer_index -= 1
# --> 826 self._check_buffer()
#
# File c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\rich\console.py:2038, in Console._check_buffer(self)
#    2035     return
#    2037 try:
# -> 2038     self._write_buffer()
#    2039 except BrokenPipeError:
#    2040     self.on_broken_pipe()
#
# RecursionError: maximum recursion depth exceeded
