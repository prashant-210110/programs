# %%
from sklearn.datasets import make_s_curve
x,y=make_s_curve(n_samples=130,noise=0.1,random_state=42)

# %%
print(x,y)
# Out:
# [[-0.91970863  0.89723399  0.56595957]
#  [-1.00833969  0.50705017 -1.56776963]
#  [ 0.85215096  0.23850606 -1.38105358]
#  [ 0.85759933  0.58550491 -0.39850685]
#  [ 0.20849204  1.89339986  1.92499608]
#  [ 0.2057933   0.57868969  2.01634382]
#  [ 0.7161006   1.13509322  1.50925757]
#  [-0.39839943  1.39133218 -1.97457191]
#  [ 0.86665262  0.64470949 -0.35933212]
#  [ 0.97619581  1.91142558 -1.30466102]
#  [ 1.03274489  1.96618774  1.13973948]
#  [-0.57478315  0.44719214 -1.33738872]
#  [ 0.06548353  0.91227497 -2.02746994]
#  [-0.30372563  0.62612534  1.67858485]
#  [-0.04697796  0.59417765  1.83829323]
#  [-0.09195787  0.02307958  2.12427061]
#  [-0.99417526  1.17202484  1.43525161]
#  [ 0.30710952  1.02856304 -0.05200035]
#  [-0.67560279 -0.04185093  0.25639865]
#  [-0.94597551  0.41654655  1.41761488]
#  [ 0.82096343  1.74468735 -0.1981786 ]
#  [ 0.26149484  0.45777907  2.07934332]
#  [-0.69412824  0.3208805   1.36572584]
#  [-1.13866688  1.12644114  0.59816252]
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(x[:,0],x[:,1],x[:,2],c=y)
# Out:
# c:\Users\prasa\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\collections.py:999: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
