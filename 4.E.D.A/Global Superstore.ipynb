# %%
import pandas as pd
df=pd.read_excel(r"c:\DATA SCIENCE\Machine_Learning\intenship\Global Superstore.xls")
df.head()
# Out:
#    Row ID         Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891 2012-07-31 2012-07-31      Same Day    RH-19495
# 1   26341    IN-2013-77878 2013-02-05 2013-02-07  Second Class    JR-16210
# 2   25330    IN-2013-71249 2013-10-17 2013-10-18   First Class    CR-12730
# 3   13524  ES-2013-1579342 2013-01-28 2013-01-30   First Class    KM-16375
# 4   47221     SG-2013-4320 2013-11-05 2013-11-06      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# ...

# %%
df.shape
# Out:
# (51290, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51290 non-null  int64
#  1   Order ID        51290 non-null  object
#  2   Order Date      51290 non-null  datetime64[ns]
#  3   Ship Date       51290 non-null  datetime64[ns]
#  4   Ship Mode       51290 non-null  object
#  5   Customer ID     51290 non-null  object
#  6   Customer Name   51290 non-null  object
#  7   Segment         51290 non-null  object
#  8   City            51290 non-null  object
#  9   State           51290 non-null  object
#  10  Country         51290 non-null  object
#  11  Postal Code     9994 non-null   float64
#  12  Market          51290 non-null  object
#  13  Region          51290 non-null  object
#  14  Product ID      51290 non-null  object
#  15  Category        51290 non-null  object
# ...

# %%
df_num=df.select_dtypes(include="number")
df_cat=df.select_dtypes(include=["category","object"])
df_date=df.select_dtypes(include="datetime64")

# %%
df_num.shape,df_cat.shape,df_date.shape
# Out:
# ((51290, 7), (51290, 15), (51290, 2))

# %%
df.isnull().sum().sum()
# Out:
# np.int64(41296)

# %%
df_num.shape
# Out:
# (51290, 7)

# %%
df_num.isnull().sum()
#postel code having more then 70% null values so i drop this colum
# Out:
# Row ID               0
# Postal Code      41296
# Sales                0
# Quantity             0
# Discount             0
# Profit               0
# Shipping Cost        0
# dtype: int64

# %%
df_num.drop("Postal Code",axis=1,inplace=True)

# %%
df_num.isnull().sum()
# Out:
# Row ID           0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# Shipping Cost    0
# dtype: int64

# %%
df_cat.isnull().sum()
#no null values in categorical data
# Out:
# Order ID          0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# City              0
# State             0
# Country           0
# Market            0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Order Priority    0
# dtype: int64

# %%
df_date.isnull().sum()
# Out:
# Order Date    0
# Ship Date     0
# dtype: int64

# %%
df.duplicated().sum()
#no duplicates and no null values
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#    Row ID         Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891 2012-07-31 2012-07-31      Same Day    RH-19495
# 1   26341    IN-2013-77878 2013-02-05 2013-02-07  Second Class    JR-16210
# 2   25330    IN-2013-71249 2013-10-17 2013-10-18   First Class    CR-12730
# 3   13524  ES-2013-1579342 2013-01-28 2013-01-30   First Class    KM-16375
# 4   47221     SG-2013-4320 2013-11-05 2013-11-06      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  ...  \
# 0       Rick Hansen     Consumer  New York City         New York  ...
# 1     Justin Ritter    Corporate     Wollongong  New South Wales  ...
# 2      Craig Reiter     Consumer       Brisbane       Queensland  ...
# 3  Katherine Murray  Home Office         Berlin           Berlin  ...
# 4       Rick Hansen     Consumer          Dakar            Dakar  ...
#
#          Product ID    Category Sub-Category  \
# ...

# %%
df_cat.columns
# Out:
# Index(['Order ID', 'Ship Mode', 'Customer ID', 'Customer Name', 'Segment',
#        'City', 'State', 'Country', 'Market', 'Region', 'Product ID',
#        'Category', 'Sub-Category', 'Product Name', 'Order Priority'],
#       dtype='object')

# %%
df["Category"].value_counts()       #contains 3
df["Sub-Category"].value_counts()   #contains 17
df["Order Priority"].value_counts()  #contain 4
df["Segment"].value_counts()            #3
df_cat["Market"].value_counts()
# Out:
# Market
# APAC      11002
# LATAM     10294
# EU        10000
# US         9994
# EMEA       5029
# Africa     4587
# Canada      384
# Name: count, dtype: int64

# %%
df.head(2)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0   32298  CA-2012-124891 2012-07-31 2012-07-31      Same Day    RH-19495
# 1   26341   IN-2013-77878 2013-02-05 2013-02-07  Second Class    JR-16210
#
#    Customer Name    Segment           City            State  ...  \
# 0    Rick Hansen   Consumer  New York City         New York  ...
# 1  Justin Ritter  Corporate     Wollongong  New South Wales  ...
#
#         Product ID    Category Sub-Category  \
# 0  TEC-AC-10003033  Technology  Accessories
# 1  FUR-CH-10003950   Furniture       Chairs
#
#                                         Product Name     Sales Quantity  \
# 0  Plantronics CS510 - Over-the-Head monaural Wir...  2309.650        7
# 1          Novimex Executive Leather Armchair, Black  3709.395        9
#
#   Discount    Profit  Shipping Cost  Order Priority
# 0      0.0  762.1845         933.57        Critical
# 1      0.1 -288.7650         923.63        Critical
#
# [2 rows x 24 columns]

# %%
df.columns=df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
df.drop(['Row ID', 'Order ID','Customer ID','Postal Code'],axis=1,inplace=True)

# %%
df_num.drop("Row ID",axis=1,inplace=True)
df_num.columns
# Out:
# Index(['Sales', 'Quantity', 'Discount', 'Profit', 'Shipping Cost'], dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(df_num.corr(),annot=True)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Order Date', 'Ship Date', 'Ship Mode', 'Customer Name', 'Segment',
#        'City', 'State', 'Country', 'Market', 'Region', 'Product ID',
#        'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity',
#        'Discount', 'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %% [markdown]
# visualizations

# %%
df.columns
# Out:
# Index(['Order Date', 'Ship Date', 'Ship Mode', 'Customer Name', 'Segment',
#        'City', 'State', 'Country', 'Market', 'Region', 'Product ID',
#        'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity',
#        'Discount', 'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
sns.pairplot(data=df)

# %%
sns.countplot(df["Ship Mode"])
# Out:
# <Axes: xlabel='count', ylabel='Ship Mode'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=df["Sales"],y=df["Country"])
# Out:
# <Axes: xlabel='Sales', ylabel='Country'>

# %%
#univarient 
sns.countplot(x="Quantity",data=df)
# Out:
# <Axes: xlabel='Quantity', ylabel='count'>

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x="Order Date",y="Sales",data=df,ci=False,markers=True)
# Out:
# C:\Users\prasa\AppData\Local\Temp\ipykernel_38356\3824382273.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.lineplot(x="Order Date",y="Sales",data=df,ci=False,markers=True)
# <Axes: xlabel='Order Date', ylabel='Sales'>

# %%
df.columns
# Out:
# Index(['Order Date', 'Ship Date', 'Ship Mode', 'Customer Name', 'Segment',
#        'City', 'State', 'Country', 'Market', 'Region', 'Product ID',
#        'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity',
#        'Discount', 'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
sns.lineplot(x="Product Name",y="Profit",data=df)
# Out:
# <Axes: xlabel='Product Name', ylabel='Profit'>

# %%
sns.barplot(x="Category",y="Sales",data=df)
# Out:
# <Axes: xlabel='Category', ylabel='Sales'>
