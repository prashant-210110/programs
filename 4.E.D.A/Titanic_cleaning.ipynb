# %%
import pandas as pd
df=pd.read_csv(r"c:\DATA SCIENCE\Machine_Learning\logistic regession\Data_Sets\titanic_train.csv")
df.head()

# %%
df.info()

# %%
df.isnull().sum()

# %%
df["Age"]=df["Age"].fillna(df["Age"].mean())
df["Age"].isnull().sum()
