# %%
import pandas as pd

# %%
df=pd.read_csv(r"c:\DATA SCIENCE\EDA\data sets\mehfil_dilsukhnagar_revenue_jan_mar_2025.csv")
df.head()
# Out:
#          Date        Item Name  Quantity  Price per Unit  Total Price  \
# 0  2025-01-01  Chicken Biryani         1             220          220
# 1  2025-01-01       Jeera Rice         2             100          200
# 2  2025-01-01  Chicken Biryani         1             220          220
# 3  2025-01-01      Butter Naan         1              30           30
# 4  2025-01-01  Chicken Biryani         5             220         1100
#
#   Order Type        Branch
# 0     Online  Dilsukhnagar
# 1    Dine-In  Dilsukhnagar
# 2     Online  Dilsukhnagar
# 3    Dine-In  Dilsukhnagar
# 4   Takeaway  Dilsukhnagar

# %%
df.shape
# Out:
# (3123, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3123 entries, 0 to 3122
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            3123 non-null   object
#  1   Item Name       3123 non-null   object
#  2   Quantity        3123 non-null   int64
#  3   Price per Unit  3123 non-null   int64
#  4   Total Price     3123 non-null   int64
#  5   Order Type      3123 non-null   object
#  6   Branch          3123 non-null   object
# dtypes: int64(3), object(4)
# memory usage: 170.9+ KB

# %%
df.describe()
# Out:
#           Quantity  Price per Unit  Total Price
# count  3123.000000     3123.000000  3123.000000
# mean      2.952930      140.691643   420.374640
# std       1.429989       87.296402   357.749506
# min       1.000000       20.000000    20.000000
# 25%       2.000000       40.000000   120.000000
# 50%       3.000000      130.000000   300.000000
# 75%       4.000000      220.000000   600.000000
# max       5.000000      300.000000  1500.000000

# %%
df.isnull().sum()
# Out:
# Date              0
# Item Name         0
# Quantity          0
# Price per Unit    0
# Total Price       0
# Order Type        0
# Branch            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(308)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (2815, 7)

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#          Date             Item Name  Quantity  Price per Unit  Total Price  \
# 0  2025-01-01       Chicken Biryani         1             220          220
# 1  2025-01-01            Jeera Rice         2             100          200
# 3  2025-01-01           Butter Naan         1              30           30
# 4  2025-01-01       Chicken Biryani         5             220         1100
# 5  2025-01-01  Paneer Butter Masala         4             180          720
#
#   Order Type        Branch
# 0     Online  Dilsukhnagar
# 1    Dine-In  Dilsukhnagar
# 3    Dine-In  Dilsukhnagar
# 4   Takeaway  Dilsukhnagar
# 5     Online  Dilsukhnagar

# %%
df.drop("Branch",axis=1,inplace=True)  
df.head()
# Out:
#          Date             Item Name  Quantity  Price per Unit  Total Price  \
# 0  2025-01-01       Chicken Biryani         1             220          220
# 1  2025-01-01            Jeera Rice         2             100          200
# 3  2025-01-01           Butter Naan         1              30           30
# 4  2025-01-01       Chicken Biryani         5             220         1100
# 5  2025-01-01  Paneer Butter Masala         4             180          720
#
#   Order Type
# 0     Online
# 1    Dine-In
# 3    Dine-In
# 4   Takeaway
# 5     Online

# %%
df["year"]=df["Date"].str.split("-").str[0]
df["month"]=df["Date"].str.split("-").str[1]
df["day"]=df["Date"].str.split("-").str[-1]

# %%
df.head()
# Out:
#          Date             Item Name  Quantity  Price per Unit  Total Price  \
# 0  2025-01-01       Chicken Biryani         1             220          220
# 1  2025-01-01            Jeera Rice         2             100          200
# 3  2025-01-01           Butter Naan         1              30           30
# 4  2025-01-01       Chicken Biryani         5             220         1100
# 5  2025-01-01  Paneer Butter Masala         4             180          720
#
#   Order Type  year month day
# 0     Online  2025    01  01
# 1    Dine-In  2025    01  01
# 3    Dine-In  2025    01  01
# 4   Takeaway  2025    01  01
# 5     Online  2025    01  01

# %%
#univariate analysis
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
sns.countplot(df["Item Name"])
# Out:
# <Axes: xlabel='count', ylabel='Item Name'>

# %%
sns.countplot(df["Order Type"])
# Out:
# <Axes: xlabel='count', ylabel='Order Type'>

# %%
#having 1 outlier
sns.boxplot(df["Total Price"])
# Out:
# <Axes: ylabel='Total Price'>

# %%
df["Price per Unit"].value_counts()
# Out:
# Price per Unit
# 120    289
# 250    264
# 130    264
# 30     259
# 220    258
# 40     257
# 180    257
# 150    252
# 300    251
# 20     237
# 100    227
# Name: count, dtype: int64

# %%
df["Quantity"].value_counts()
# Out:
# Quantity
# 1    593
# 2    579
# 4    558
# 5    549
# 3    536
# Name: count, dtype: int64

# %%
df.head()
# Out:
#          Date             Item Name  Quantity  Price per Unit  Total Price  \
# 0  2025-01-01       Chicken Biryani         1             220          220
# 1  2025-01-01            Jeera Rice         2             100          200
# 3  2025-01-01           Butter Naan         1              30           30
# 4  2025-01-01       Chicken Biryani         5             220         1100
# 5  2025-01-01  Paneer Butter Masala         4             180          720
#
#   Order Type  year month day
# 0     Online  2025    01  01
# 1    Dine-In  2025    01  01
# 3    Dine-In  2025    01  01
# 4   Takeaway  2025    01  01
# 5     Online  2025    01  01

# %%
df["month"].unique()
# Out:
# array(['01', '02', '03'], dtype=object)

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x=df["day"],y=df["Total Price"],palette="winter",ci=None)
# Out:
# C:\Users\prasa\AppData\Local\Temp\ipykernel_32096\4159156685.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x=df["day"],y=df["Total Price"],palette="winter",ci=None)
# C:\Users\prasa\AppData\Local\Temp\ipykernel_32096\4159156685.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(x=df["day"],y=df["Total Price"],palette="winter",ci=None)
# <Axes: xlabel='day', ylabel='Total Price'>

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x=df["day"],y=df["Total Price"],palette="winter",ci=None,markers=True)
# Out:
# C:\Users\prasa\AppData\Local\Temp\ipykernel_32096\4157376552.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x=df["day"],y=df["Total Price"],palette="winter",ci=None,markers=True)
# C:\Users\prasa\AppData\Local\Temp\ipykernel_32096\4157376552.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(x=df["day"],y=df["Total Price"],palette="winter",ci=None,markers=True)
# <Axes: xlabel='day', ylabel='Total Price'>

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x=df["day"],y=df["Total Price"],palette="winter",ci=None,hue=df["month"])
# Out:
# C:\Users\prasa\AppData\Local\Temp\ipykernel_32096\1259653478.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x=df["day"],y=df["Total Price"],palette="winter",ci=None,hue=df["month"])
# <Axes: xlabel='day', ylabel='Total Price'>
