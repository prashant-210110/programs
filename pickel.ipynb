# %%
# !pip install PKL
# Out:
# ERROR: Could not find a version that satisfies the requirement PKL (from versions: none)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for PKL

# %%
import pickle 
data={"a":[1,2,3,4],"b":"Data Science",(1,2):[1,2]}
with open("data.pickle","wb") as FPK:
  pickle.dump(data,FPK)
print("Pickle File Created")
print(data)
# Out:
# Pickle File Created
# {'a': [1, 2, 3, 4], 'b': 'Data Science', (1, 2): [1, 2]}
