# %%
! pip install -U phidata
! pip install google-generativeai
# Out:
# ^C
# ...
# c:\users\prasa\appdata\local\programs\python\python313\lib\site-packages
# (2.7.10)
# ...
# c:\users\prasa\appdata\local\programs\python\python313\lib\site-packages (from
# phidata) (0.17.0)
# ...
# c:\users\prasa\appdata\local\programs\python\python313\lib\site-packages (from
# phidata) (3.1.45)
# ...
# c:\users\prasa\appdata\local\programs\python\python313\lib\site-packages (from
# phidata) (0.28.1)
# ...
# c:\users\prasa\appdata\local\programs\python\python313\lib\site-packages (from
# phidata) (2.12.5)
# ...
# c:\users\prasa\appdata\local\programs\python\python313\lib\site-packages (from
# phidata) (2.12.0)
# ...
# c:\users\prasa\appdata\local\programs\python\python313\lib\site-packages (from
# phidata) (1.2.1)
# ...
# c:\users\prasa\appdata\local\programs\python\python313\lib\site-packages (from
# phidata) (6.0.3)
# ...
# c:\users\prasa\appdata\local\programs\python\python313\lib\site-packages (from
# phidata) (14.2.0)
# ...
# c:\users\prasa\appdata\local\programs\python\python313\lib\site-packages (from
# phidata) (2.3.0)
# ...

# %%
! pip install google-generativeai

# %%
! pip install duckduckgo-search
# Out:
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.0 MB ? eta -:--:--
#    ------------- -------------------------- 1.3/4.0 MB 5.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.9/4.0 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 6.1 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    ---------------- ----------------------- 1.3/3.1 MB 8.2 MB/s eta 0:00:01
#    ------------------- -------------------- 1.6/3.1 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------  3.1/3.1 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------- 3.1/3.1 MB 4.6 MB/s  0:00:00
# ...
#
#    ------------- -------------------------- 1/3 [lxml]
#    ------------- -------------------------- 1/3 [lxml]
#    ------------- -------------------------- 1/3 [lxml]
#    ------------- -------------------------- 1/3 [lxml]
# ...

# %%
import os
from phi.agent import Agent
from phi.model.google import gemini
from phi.tools.duckduckgo import DuckDuckGo

# %%
os.environ["GOOGLE_API_KEY"] = "AIzaSyCMusj1vhFqhimL_Fk_-EF8xsLCJ0PRvAM"

# %%
agent=Agent(
    name="agent",
    model=gemini.Gemini(model="gemini-1.5-flash"),
    tools=[DuckDuckGo()],
    instructions=["Always include sources"],
    show_tool_calls=True,
)

# %%
res=agent.print_response("what is machine learning",stream=True)
res
# Out:
# ▰▱▱▱▱▱▱ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ what is machine learning                                                    │
# │                                                                             │
# ▰▰▰▰▰▰▰ Thinking...───────────┘
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ what is machine learning                                                    │
# │                                                                             │
# ▰▰▰▰▰▰▱ Thinking...───────────┘
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ what is machine learning                                                    │
# ...

# %%
import os
from phi.agent import Agent
from phi.model.google import Gemini
from phi.tools.duckduckgo import DuckDuckGo

# 1. Set your Gemini API Key
# You can also set this as an environment variable: export GOOGLE_API_KEY=your_key
os.environ["GOOGLE_API_KEY"] = "AIzaSyCMusj1vhFqhimL_Fk_-EF8xsLCJ0PRvAM"

# 2. Create the Agent
agent1 = Agent(
    name="Gemini Search Agent",
    model=Gemini(id="gemini-2.5-flash"), # You can also use "gemini-1.5-pro"
    tools=[DuckDuckGo()],
    instructions=[
        "Search for the user's query using DuckDuckGo.",
        "Provide a concise summary of the findings.",
        "Always include the sources/links for the information found."
    ],
    show_tool_calls=True,
    markdown=True,
)

# 3. Run the Agent
agent1.print_response("WHAT is machine learning?", stream=True)
# Out:
# ▰▱▱▱▱▱▱ Thinking...
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ WHAT is machine learning?                                                   │
# │                                                                             │
# ▰▰▰▰▰▰▰ Thinking...───────────┘
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ WHAT is machine learning?                                                   │
# │                                                                             │
# ▰▰▰▰▰▰▱ Thinking...───────────┘
# ┌─ Message ───────────────────────────────────────────────────────────────────┐
# │                                                                             │
# │ WHAT is machine learning?                                                   │
# ...
