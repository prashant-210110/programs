# %%
# !pip install pandas
import numpy as np
import pandas as pd
# Out:
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.0 MB 700.7 kB/s eta 0:00:15
#    -- ------------------------------------- 0.8/11.0 MB 896.1 kB/s eta 0:00:12
# ...

# %%
a=np.array([15,48,59,36,25,14,59,26])
s=pd.Series(a,name="data")
s
# Out:
# 0    15
# 1    48
# 2    59
# 3    36
# 4    25
# 5    14
# 6    59
# 7    26
# Name: data, dtype: int64

# %%
s[s>30]
# Out:
# 1    48
# 2    59
# 3    36
# 6    59
# Name: data, dtype: int64

# %%
s[(s>=30) & (s<=50)]
# Out:
# 1    48
# 3    36
# Name: data, dtype: int64

# %%
s[2]=60
print(s)
# Out:
# 0    15
# 1    48
# 2    60
# 3    36
# 4    25
# 5    14
# 6    59
# 7    26
# Name: data, dtype: int64

# %%
#DataFrame
a={"name":["sai","valli","akki","meow"],
   "age":[21,18,19,15],
   "place":["bpt","hyd","ong","gun"],
   "occupation":["study","study","study","job"]
   }
index=["0","1","2","3"]
d=pd.DataFrame(a)
d
# Out:
#     name  age place occupation
# 0    sai   21   bpt      study
# 1  valli   18   hyd      study
# 2   akki   19   ong      study
# 3   meow   15   gun        job

# %%
d.head(2)
# Out:
#     name  age place occupation
# 0    sai   21   bpt      study
# 1  valli   18   hyd      study

# %%
d.tail(2)
# Out:
#    name  age place occupation
# 2  akki   19   ong      study
# 3  meow   15   gun        job

# %%
d.iloc[0:3]
# Out:
#     name  age place occupation
# 0    sai   21   bpt      study
# 1  valli   18   hyd      study
# 2   akki   19   ong      study

# %%
d.index=["1","2","3","4"]
d.loc[["1","2","3"],["name","age","place"]]
# Out:
#     name  age place
# 1    sai   21   bpt
# 2  valli   18   hyd
# 3   akki   19   ong

# %%
d["name"]
# Out:
# 1      sai
# 2    valli
# 3     akki
# 4     meow
# Name: name, dtype: object

# %%
d[["name","age","place"]]
# Out:
#     name  age place
# 1    sai   21   bpt
# 2  valli   18   hyd
# 3   akki   19   ong
# 4   meow   15   gun

# %%
d.drop("2",axis=0)
# Out:
#    name  age place occupation
# 1   sai   21   bpt      study
# 3  akki   19   ong      study
# 4  meow   15   gun        job

# %%
d
# Out:
#     name  age place occupation
# 1    sai   21   bpt      study
# 2  valli   18   hyd      study
# 3   akki   19   ong      study
# 4   meow   15   gun        job

# %%
d.shape
# Out:
# (4, 4)

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 1 to 4
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        4 non-null      object
#  1   age         4 non-null      int64
#  2   place       4 non-null      object
#  3   occupation  4 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 332.0+ bytes

# %%
d.describe()
# Out:
#          age
# count   4.00
# mean   18.25
# std     2.50
# min    15.00
# 25%    17.25
# 50%    18.50
# 75%    19.50
# max    21.00

# %%
d
# Out:
#     name  age place occupation
# 1    sai   21   bpt      study
# 2  valli   18   hyd      study
# 3   akki   19   ong      study
# 4   meow   15   gun        job

# %%
d.at["3","age"]=17

# %%
d
# Out:
#     name  age place occupation
# 1    sai   21   bpt      study
# 2  valli   18   hyd      study
# 3   akki   17   ong      study
# 4   meow   15   gun        job

# %%
d.at["2","place"]
# Out:
# 'hyd'

# %%
d["age"]=d["age"]-2

# %%
d.at["2","place"]="bpt"
d
# Out:
#     name  age place occupation
# 1    sai   25   bpt      study
# 2  valli   22   bpt      study
# 3   akki   21   ong      study
# 4   meow   19   gun        job

# %%
d.rename(columns={"occupation":"occ"},inplace=True)
d
# Out:
#     name  age place    occ
# 1    sai   25   bpt  study
# 2  valli   22   bpt  study
# 3   akki   21   ong  study
# 4   meow   19   gun    job

# %%
d["place"].unique()
# Out:
# array(['bpt', 'ong', 'gun'], dtype=object)

# %%
d["occ"].value_counts()
# Out:
# occ
# study    3
# job      1
# Name: count, dtype: int64

# %%
d["ph.no"]=['9676493786','6300295359','9491668716',"784715121"]
d
# Out:
#     name  age place    occ       ph.no
# 1    sai   23   bpt  study  9676493786
# 2  valli   20   bpt  study  6300295359
# 3   akki   19   ong  study  9491668716
# 4   meow   17   gun    job   784715121

# %%
d.at["1","age"]=None
d.drop(2,axis=0,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[131], line 2
#       1 d.at["1","age"]=None
# ----> 2 d.drop(2,axis=0,inplace=True)
#
# File c:\Users\prasa\PycharmProjects\programs\programs\venv\Lib\site-packages\pandas\core\frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)   5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
#    5592         columns=columns,
#    5593         level=level,
#    5594         inplace=inplace,
# ...

# %%
d.at["4","ph.no"]=None
d
# Out:
#     name   age place    occ       ph.no
# 1    sai   NaN   bpt  study  9676493786
# 2  valli  20.0   bpt  study  6300295359
# 3   akki  19.0   ong  study  9491668716
# 4   meow  17.0   gun    job        None

# %%
d.dropna()
# Out:
#     name   age place    occ       ph.no
# 2  valli  20.0   bpt  study  6300295359
# 3   akki  19.0   ong  study  9491668716

# %%
d.dropna(how="any")
# Out:
#     name   age place    occ       ph.no
# 2  valli  20.0   bpt  study  6300295359
# 3   akki  19.0   ong  study  9491668716

# %%
d.dropna(how="all")
# Out:
#     name   age place    occ       ph.no
# 1    sai   NaN   bpt  study  9676493786
# 2  valli  20.0   bpt  study  6300295359
# 3   akki  19.0   ong  study  9491668716
# 4   meow  17.0   gun    job        None

# %%
d["age"].fillna(d["age"].mean(),inplace=True)
d
# Out:
# C:\Users\prasa\AppData\Local\Temp\ipykernel_11448\2490615929.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d["age"].fillna(d["age"].mean(),inplace=True)
#     name        age place    occ       ph.no
# 1    sai  18.666667   bpt  study  9676493786
# 2  valli  20.000000   bpt  study  6300295359
# 3   akki  19.000000   ong  study  9491668716
# 4   meow  17.000000   gun    job        None

# %%
d.at["1","age"]=None
d["age"].fillna(method="bfill",inplace=True)
d["ph.no"].fillna(method="ffill",inplace=True)
d
# Out:
# C:\Users\prasa\AppData\Local\Temp\ipykernel_11448\906345120.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   d["age"].fillna(method="bfill",inplace=True)
# C:\Users\prasa\AppData\Local\Temp\ipykernel_11448\906345120.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   d["age"].fillna(method="bfill",inplace=True)
# ...
